# %%
import numpy as np, healpy as hp, plottools as pl, local, tools_cmb, quad_func, binning as bn, analysis as ana
from matplotlib.pyplot import *
import warnings
warnings.filterwarnings("ignore")

# %%
#qid = 'boss_s15d'
#qid = 'boss_s15dn'
qid = 'boss_s16d'
#qid = 'boss_alld'
#qid = 'boss_alldn'

# %%
dirs = local.data_directory()
rlmax = 3000
rlmin = 500
aobj1 = local.init_analysis_params(qid=qid,fltr='none',wind='com16',ivar='noivar',ptsr='base')
qobj1 = quad_func.reconstruction(dirs['local'],aobj1.ids,stag=aobj1.stag,rlmin=rlmin,qlist=['TT'])
Qobj1 = quad_func.reconstruction(dirs['local'],aobj1.ids,stag=aobj1.stag,rlmin=rlmin,qlist=['TT'],bhe=['src'])

# %%
cl1 = local.plot_bias(qobj1)

# %%
cl1 = local.plot_bias(qobj1,frac=True,normcorr=True,r2=1.,r4=1.)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0f2bf70ec95b> in <module>
# ----> 1 cl1 = plot_bias(qobj1,frac=True,normcorr=True,r2=1.,r4=1.)
#
# NameError: name 'plot_bias' is not defined

# %% [markdown]
# ### Real data

# %%
local.plot_spec_kk(qobj1,yrange=True)
local.plot_spec_kk(qobj1,plot_real=True,yrange=True)
local.plot_spec_kk(Qobj1,plot_real=True,yrange=True)
# Out:
# 8.743462915234693
# obs A 1.0 mean(A) 1.0 sigma(A) 0.157 S/N 6.357 A>oA 0.96
# 8.743462915234693
# obs A 1.0 mean(A) 1.0 sigma(A) 0.157 S/N 6.357 A>oA 0.96
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-48e38b172369> in <module>
#       1 local.plot_spec_kk(qobj1,yrange=True)
#       2 local.plot_spec_kk(qobj1,plot_real=True,yrange=True)
# ----> 3 local.plot_spec_kk(Qobj1,plot_real=True,yrange=True)
#
# /global/u1/t/toshiyan/Work/Ongoing/act_lens/local.py in plot_spec_kk(qobj, rlz, cn, lmin, lmax, bnum, output, verbose, lfac, plot_real, yrange)
#     386     # compute binned spectrum
#     387     mb = bn.multipole_binning(bnum,lmin=lmin,lmax=lmax)
# --> 388     Mkk, Vkk, Skk, Okk, nb = load_spec(qobj,mb,rlz=rlz,cn=cn,outN0=True)
#     389     if verbose: print(np.sqrt(np.sum(Mkk**2/Vkk**2)))
#     390     # statistics
#
# ...

# %%
aobj2 = local.init_analysis_params(qid='comb_d',fltr='none',wind='com16',ivar='noivar',ptsr='PT')
qobj2 = quad_func.reconstruction(dirs['local'],aobj2.ids,stag=aobj2.stag,rlmin=rlmin,qlist=['TT'])
Qobj2 = quad_func.reconstruction(dirs['local'],aobj2.ids,stag=aobj2.stag,rlmin=rlmin,qlist=['TT'],bhe=['src'])
local.plot_spec_kk(qobj2,yrange=True)
local.plot_spec_kk(qobj2,plot_real=True,yrange=True)
local.plot_spec_kk(Qobj2,plot_real=True,yrange=True)
